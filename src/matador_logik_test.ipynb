# %% [markdown]
# # MATADOR LOGIK TEST

# %%
import importlib
from backend.bræt import Bræt, Spiller, Felt, NAMES, priser
importlib.reload(importlib.import_module("backend.bræt"))

# %%
player1 = Spiller("Galea")

# %%
print(player1)
# Out:
# Galea er på START og har 1500 kr. og ejendomme: []

# %%
bræt = Bræt()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 bræt = Bræt()
#
# File c:\Users\fga\Dropbox\4 - Privat\Børn\Matador\src\backend\bræt.py:6, in Bræt.__init__(self, antal_spillere, antal_brikker)
#       4 def __init__(self, antal_spillere = 4, antal_brikker = 40):
#       5     self.spillere = [Spiller(f"Spiller {i+1}", 0) for i in range(antal_spillere)]
# ----> 6     self.brikker = [Felt(NAMES[i], priser[i]) for i in range(antal_brikker)]
#
# IndexError: list index out of range
